# %% [markdown]
# <div align="right">Python 2.7 Jupyter Notebook</div>
#
# # Network Analysis Exercises Using 'Friends and Family' Dataset
# <br>
# <div class="alert alert-warning">
# <b>This notebook contains exercises for students completing the non-technical track.</b> Note that you will not be disadvantaged for completing only the non-technical notebooks. If you are a more technical student and wish to deepen your understanding and qualify for additional credit, we recommend that you complete the technical notebooks instead.
# </div>
#
# ## Part 2: Clustering
#
# ### Your completion of the notebook exercises will be graded based on your ability to:
#
# > **Evaluate**: Are you able to interpret the results and justify your interpretation based on the observed data?

# %% [markdown]
# # Notebook introduction

# %% [markdown]
# Community detection is an important task in social network analysis. The idea behind it is to identify groups of people that share a common interest, based on the assumption that these people tend to link to each other more often than to the rest of the network. Specifically, real-world networks exhibit clustering behavior that can be observed in the graph representation (of these networks) by the formation of clusters or partitions. These groups of nodes on a graph (clusters) correspond to communities that share common properties, or have a common role in the system under study.
#
# Intuitively, it is expected that such clusters are associated with a high concentration of nodes. In the following examples, you will explore the identification of these clusters using the following approaches as discussed in the video lectures:
#
# 1. Hierarchical clustering (using a distance matrix);
# 2. The Louvain Algorithm (using modularity maximization); and
# 3. Spectral graph partitioning.

# %% [markdown]
# <br>
# <div class="alert alert-warning">
# <b>Some students experienced issues with the incorrect versions of sklearn and scipy modules on their environments.</b><br>The code cells below will remove and reinstall these modules. The first cell may produce errors depending on the current state of your virtual analysis environment. It is important that the second cell completes successfully. It should state "Successfully installed scipy" and "Successfully installed scikit-learn" in the output.
# </div>

# %%
# Uninstall existing broken installs.
# !sudo /usr/bin/yes | pip uninstall scikit-learn
# !sudo /usr/bin/yes | pip uninstall scipy
# Out:
# Uninstalling scikit-learn-0.17.1:
#   /home/ubuntu/.local/lib/python2.7/site-packages/scikit_learn-0.17.1.dist-info/DESCRIPTION.rst
#   /home/ubuntu/.local/lib/python2.7/site-packages/scikit_learn-0.17.1.dist-info/INSTALLER
#   /home/ubuntu/.local/lib/python2.7/site-packages/scikit_learn-0.17.1.dist-info/METADATA
#   /home/ubuntu/.local/lib/python2.7/site-packages/scikit_learn-0.17.1.dist-info/RECORD
#   /home/ubuntu/.local/lib/python2.7/site-packages/scikit_learn-0.17.1.dist-info/WHEEL
#   /home/ubuntu/.local/lib/python2.7/site-packages/scikit_learn-0.17.1.dist-info/metadata.json
#   /home/ubuntu/.local/lib/python2.7/site-packages/scikit_learn-0.17.1.dist-info/top_level.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/.libs/libgfortran-ed201abd.so.3.0.0
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/.libs/libopenblasp-r0-39a31c03.2.18.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/__check_build/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/__check_build/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/__check_build/_check_build.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/__check_build/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/__check_build/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/_build_utils.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/_build_utils.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/_isotonic.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/calibration.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/calibration.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/_dbscan_inner.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/_feature_agglomeration.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/_feature_agglomeration.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/_hierarchical.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/_k_means.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/affinity_propagation_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/affinity_propagation_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/bicluster.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/bicluster.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/birch.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/birch.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/dbscan_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/dbscan_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/hierarchical.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/hierarchical.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/k_means_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/k_means_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/mean_shift_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/mean_shift_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/spectral.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/spectral.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/common.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/common.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_affinity_propagation.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_affinity_propagation.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_bicluster.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_bicluster.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_birch.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_birch.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_dbscan.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_dbscan.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_hierarchical.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_hierarchical.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_k_means.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_k_means.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_mean_shift.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_mean_shift.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_spectral.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cluster/tests/test_spectral.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/empirical_covariance_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/empirical_covariance_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/graph_lasso_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/graph_lasso_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/outlier_detection.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/outlier_detection.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/robust_covariance.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/robust_covariance.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/shrunk_covariance_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/shrunk_covariance_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/tests/test_covariance.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/tests/test_covariance.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/tests/test_graph_lasso.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/tests/test_graph_lasso.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/tests/test_robust_covariance.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/covariance/tests/test_robust_covariance.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cross_decomposition/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cross_decomposition/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cross_decomposition/cca_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cross_decomposition/cca_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cross_decomposition/pls_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cross_decomposition/pls_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cross_validation.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/cross_validation.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/_svmlight_format.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/california_housing.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/california_housing.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/covtype.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/covtype.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/data/boston_house_prices.csv
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/data/breast_cancer.csv
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/data/diabetes_data.csv.gz
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/data/diabetes_target.csv.gz
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/data/digits.csv.gz
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/data/iris.csv
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/data/linnerud_exercise.csv
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/data/linnerud_physiological.csv
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/descr/boston_house_prices.rst
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/descr/breast_cancer.rst
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/descr/diabetes.rst
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/descr/digits.rst
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/descr/iris.rst
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/descr/linnerud.rst
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/images/README.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/images/china.jpg
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/images/flower.jpg
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/lfw.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/lfw.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/mlcomp.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/mlcomp.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/mldata.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/mldata.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/olivetti_faces.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/olivetti_faces.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/rcv1.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/rcv1.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/samples_generator.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/samples_generator.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/species_distributions.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/species_distributions.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/svmlight_format.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/svmlight_format.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/data/svmlight_classification.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/data/svmlight_invalid.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/data/svmlight_invalid_order.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/data/svmlight_multilabel.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_20news.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_20news.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_covtype.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_covtype.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_lfw.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_lfw.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_mldata.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_mldata.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_rcv1.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_rcv1.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_samples_generator.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_samples_generator.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_svmlight_format.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/tests/test_svmlight_format.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/twenty_newsgroups.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/datasets/twenty_newsgroups.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/_online_lda.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/cdnmf_fast.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/dict_learning.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/dict_learning.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/factor_analysis.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/factor_analysis.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/fastica_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/fastica_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/incremental_pca.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/incremental_pca.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/kernel_pca.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/kernel_pca.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/nmf.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/nmf.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/online_lda.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/online_lda.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/pca.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/sparse_pca.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/sparse_pca.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_dict_learning.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_dict_learning.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_factor_analysis.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_factor_analysis.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_fastica.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_fastica.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_incremental_pca.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_incremental_pca.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_kernel_pca.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_kernel_pca.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_nmf.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_nmf.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_online_lda.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_online_lda.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_pca.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_pca.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_sparse_pca.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_sparse_pca.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_truncated_svd.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/tests/test_truncated_svd.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/truncated_svd.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/decomposition/truncated_svd.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/discriminant_analysis.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/discriminant_analysis.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/dummy.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/dummy.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/_gradient_boosting.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/bagging.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/bagging.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/forest.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/gradient_boosting.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/partial_dependence.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/partial_dependence.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_bagging.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_bagging.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_forest.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_forest.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_gradient_boosting.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_gradient_boosting.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_gradient_boosting_loss_functions.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_gradient_boosting_loss_functions.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_partial_dependence.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_partial_dependence.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_voting_classifier.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_voting_classifier.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_weight_boosting.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/tests/test_weight_boosting.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/voting_classifier.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/voting_classifier.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/funcsigs.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/funcsigs.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_compat.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_compat.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_memory_helpers.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_memory_helpers.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_multiprocessing_helpers.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_multiprocessing_helpers.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/disk.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/disk.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/format_stack.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/format_stack.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/func_inspect.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/func_inspect.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/logger.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/logger.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/memory.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/memory.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/my_exceptions.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/my_exceptions.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/numpy_pickle.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/numpy_pickle.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/pool.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/pool.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/testing.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/joblib/testing.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/odict.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/odict.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/six.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/six.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/test_externals_setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/externals/test_externals_setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/_hashing.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/hashing.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/hashing.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/image.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/image.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/stop_words.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/stop_words.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/test_dict_vectorizer.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/test_dict_vectorizer.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/test_feature_hasher.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/test_feature_hasher.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/test_image.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/test_image.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/test_text.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/tests/test_text.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/text.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/from_model.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/from_model.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/rfe.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/rfe.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_chi2.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_chi2.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_feature_select.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_feature_select.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_from_model.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_from_model.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_rfe.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_rfe.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_variance_threshold.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/tests/test_variance_threshold.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/univariate_selection.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/univariate_selection.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/variance_threshold.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/feature_selection/variance_threshold.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/correlation_models.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/correlation_models.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/gaussian_process.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/gaussian_process.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/regression_models.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/regression_models.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/tests/test_gaussian_process.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/gaussian_process/tests/test_gaussian_process.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/grid_search.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/grid_search.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/isotonic.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/isotonic.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/kernel_approximation.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/kernel_approximation.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/kernel_ridge.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/kernel_ridge.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/lda.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/lda.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/learning_curve.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/learning_curve.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/bayes.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/bayes.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/cd_fast.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/least_angle.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/least_angle.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/logistic.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/omp.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/omp.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/passive_aggressive.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/passive_aggressive.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/perceptron.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/perceptron.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/randomized_l1.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/randomized_l1.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/ransac.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/ransac.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/ridge.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/ridge.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/sag.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/sag.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/sag_fast.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/sgd_fast.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/stochastic_gradient.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/stochastic_gradient.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_bayes.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_bayes.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_coordinate_descent.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_coordinate_descent.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_least_angle.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_least_angle.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_logistic.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_logistic.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_omp.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_omp.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_passive_aggressive.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_passive_aggressive.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_perceptron.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_perceptron.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_randomized_l1.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_randomized_l1.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_ransac.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_ransac.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_ridge.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_ridge.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_sag.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_sag.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_sgd.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_sgd.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_sparse_coordinate_descent.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_sparse_coordinate_descent.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_theil_sen.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/tests/test_theil_sen.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/theil_sen.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/linear_model/theil_sen.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/_barnes_hut_tsne.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/_utils.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/isomap.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/isomap.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/locally_linear.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/locally_linear.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/mds.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/mds.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/spectral_embedding_.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/spectral_embedding_.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/t_sne.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/classification.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/classification.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/bicluster.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/bicluster.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/expected_mutual_info_fast.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/supervised.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/supervised.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/tests/test_bicluster.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/tests/test_bicluster.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/tests/test_supervised.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/tests/test_supervised.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/tests/test_unsupervised.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/tests/test_unsupervised.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/unsupervised.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/cluster/unsupervised.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/metrics.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/metrics.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/pairwise.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/pairwise_fast.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/ranking.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/ranking.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/regression.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/regression.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/scorer.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/scorer.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_classification.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_classification.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_common.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_common.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_pairwise.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_pairwise.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_ranking.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_ranking.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_regression.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_regression.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_score_objects.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/metrics/tests/test_score_objects.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/dpgmm.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/dpgmm.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/gmm.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/gmm.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/tests/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/tests/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/tests/test_dpgmm.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/tests/test_dpgmm.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/tests/test_gmm.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/mixture/tests/test_gmm.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/multiclass.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/multiclass.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/naive_bayes.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/naive_bayes.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/__init__.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/approximate.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/approximate.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/ball_tree.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/base.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/base.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/classification.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/classification.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/dist_metrics.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/graph.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/graph.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/kd_tree.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/kde.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/kde.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/nearest_centroid.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/nearest_centroid.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/regression.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/regression.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/typedefs.so
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/unsupervised.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neighbors/unsupervised.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neural_network/__init__.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/sklearn/neural_network/__init__.pyc
# ...
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/rand-dunif.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/rand-normal.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/rand-tt800.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/rand-uniform.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/random.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/randref.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/range.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/reduce.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/shapecheck.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tau.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/timer.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tiny.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tinymat.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tinymatexpr.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tinymatio.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tinyvec-et.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tinyvec.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tinyvec.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tinyvecio.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tinyveciter.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/traversal.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/traversal.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tuning.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tvcross.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/tvecglobs.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/update.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecaccum.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecall.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecany.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecbfn.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecbops.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/veccount.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecdelta.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecdot.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecexpr.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecexprwrap.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecglobs.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecglobs.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecio.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/veciter.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecmax.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecmin.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecnorm.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecnorm1.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecpick.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecpick.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecpickio.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecpickiter.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecsum.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vector-et.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vector.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vector.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecuops.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecwhere.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/vecwhere.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/wrap-climits.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/zero.cc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz/blitz/zero.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/blitz_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/build_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/build_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/bytecodecompiler.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/bytecodecompiler.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/c_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/c_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/catalog.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/catalog.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/common_info.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/common_info.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/converters.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/converters.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/cpp_namespace_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/cpp_namespace_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/doc/tutorial.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/doc/tutorial_original.html
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/array3d.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/array3d.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/binary_search.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/binary_search.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/cast_copy_transpose.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/cast_copy_transpose.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/dict_sort.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/dict_sort.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/fibonacci.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/fibonacci.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/functional.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/functional.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/increment_example.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/increment_example.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/md5_speed.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/md5_speed.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/object.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/object.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/print_example.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/print_example.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/py_none.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/py_none.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/ramp.c
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/ramp.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/ramp.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/ramp2.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/ramp2.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/support_code_example.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/support_code_example.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/swig2_example.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/swig2_example.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/swig2_ext.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/swig2_ext.i
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/tuple_return.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/tuple_return.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/vq.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/vq.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/vtk_example.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/vtk_example.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/wx_example.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/wx_example.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/wx_speed.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/examples/wx_speed.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/ext_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/ext_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/inline_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/inline_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/numpy_scalar_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/numpy_scalar_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/platform_info.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/platform_info.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/README.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/dict.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/list.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/notes.txt
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/number.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/object.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/scxx.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/sequence.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/str.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/tuple.h
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/scxx/weave_imp.cpp
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/setup.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/setup.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/size_check.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/size_check.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/slice_handler.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/slice_handler.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/standard_array_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/standard_array_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/swig2_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/swig2_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/swigptr.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/swigptr.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/swigptr2.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/swigptr2.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/scxx_timings.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/scxx_timings.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_ast_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_ast_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_blitz_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_blitz_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_build_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_build_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_c_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_c_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_catalog.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_catalog.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_ext_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_ext_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_inline_tools.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_inline_tools.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_numpy_scalar_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_numpy_scalar_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_scxx_dict.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_scxx_dict.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_scxx_object.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_scxx_object.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_scxx_sequence.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_scxx_sequence.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_size_check.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_size_check.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_slice_handler.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_slice_handler.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_standard_array_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/test_standard_array_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/weave_test_utils.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/tests/weave_test_utils.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/vtk_spec.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/vtk_spec.pyc
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/weave_version.py
#   /home/ubuntu/.local/lib/python2.7/site-packages/scipy/weave/weave_version.pyc
# Proceed (y/n)?   Successfully uninstalled scipy-0.18.0
# /usr/bin/yes: standard output: Broken pipe

# %%
# Reinstall to sklearn and scipy.
# !pip install scipy --target=/home/ubuntu/.local/lib/python2.7/site-packages
# !pip install scikit-learn --target=/home/ubuntu/.local/lib/python2.7/site-packages
# Out:
# Collecting scipy
#   Using cached scipy-0.18.0-cp27-cp27mu-manylinux1_x86_64.whl
# Installing collected packages: scipy
# Successfully installed scipy
# Collecting scikit-learn
#   Using cached scikit_learn-0.17.1-cp27-cp27mu-manylinux1_x86_64.whl
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn

# %% [markdown]
# You can now continue with the remainder of the notebook.

# %% [markdown]
# #### Import required modules

# %%
import networkx as nx
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pylab as plt

from collections import defaultdict, Counter
import operator

## For hierarchical clustering.
from scipy.cluster import hierarchy
from scipy.spatial import distance

## For spectral graph partitioning.
from sklearn.cluster import spectral_clustering as spc

## For Community Detection (Louvain Method).
import community

import sys
sys.path.append('..')
from utils import draw_partitioned_graph

plt.rcParams['figure.figsize'] = (15, 9)
plt.rcParams['axes.titlesize'] = 'large'

# %% [markdown]
# ## 1. Data preparation

# %% [markdown]
# You are going to read the graph from an adjacency list saved in the earlier exercises.

# %%
call_adjmatrix = pd.read_csv('./call.adjmatrix', index_col=0)
call_graph     = nx.from_numpy_matrix(call_adjmatrix.as_matrix())

# %%
# Display call graph object.
plt.figure(figsize=(10,10))
plt.axis('off')

pos = nx.spring_layout(call_graph)

nx.draw_networkx_nodes(call_graph, pos=pos, node_color='#11DD11')
nx.draw_networkx_edges(call_graph, pos=pos, alpha=0.5)
plt.show()

# %% [markdown]
# ## 2. Hierarchical clustering

# %% [markdown]
# This notebook will make use of a hierarchical clustering algorithm as implemented in [Scipy](http://docs.scipy.org/doc/scipy/reference/). The following example uses the average distance measure. Since the graph is weighted, you can also use the single linkage inter-cluster distance measure (see exercises).

# %%
def create_hc(G, t=3, linkage='max'):
    """
    Creates hierarchical cluster of graph G from distance matrix
    
    'Erika Fille Legara <legareft@ihpc.a-star.edu.sg>',
    'Maksim Tsvetovat <maksim@tsvetovat.org',
    'Drew Conway <drew.conway@nyu.edu>',
    'Aric Hagberg <hagberg@lanl.gov>'
    'Gorden Jemwa <>' : modifications: set t argument with default, 
                                       accept linkage with default as an argument
    """
    path_length=nx.all_pairs_shortest_path_length(G)
    distances=np.zeros((len(G),len(G)))
    labels=G.nodes() # keep node labels.
    for u,p in path_length.items():
        for v,d in p.items():
            #distances[u][v]=d
            distances[G.nodes().index(u)][G.nodes().index(v)] = d
            distances[G.nodes().index(v)][G.nodes().index(u)] = d
            if u==v: distances[G.nodes().index(u)][G.nodes().index(u)]=0
    # Create hierarchical cluster.
    Y=distance.squareform(distances)
    if linkage == 'max':
        # Creates HC using farthest point linkage.
        Z=hierarchy.average(Y)  
    if linkage == 'single':
        # Creates HC using closest point linkage.
        Z=hierarchy.single(Y)  

    # This partition selection is arbitrary, for illustrative purposes.
    membership=list(hierarchy.fcluster(Z,t=t, criterion='inconsistent'))
    
    # Create collection of lists for blockmodel.
    partition = defaultdict(list)
    for n,p in zip(list(range(len(G))),membership):
        partition[p].append(labels[n])
    
    return Z, membership, partition

# %% [markdown]
# Below is a demonstration of hierarchical clustering when applied to the call graph.

# %%
# Perform hierarchical clustering using 'max' linkage. 
# Return the distance matrix, node membership list and collection lists for block model.
Z, membership, blk_clusters = create_hc(call_graph, t=1.15)

# %%
# Map membership values to a dictionary variable.
hc_partition = {}
i = 0
for i in range(len(membership)):
    hc_partition[i]=membership[i]

# %%
# Visualize the clustering.
plt.figure(figsize=(10,10))
plt.axis('off')

pos = nx.spring_layout(call_graph)

nx.draw_networkx_nodes(call_graph, pos=pos, node_color=hc_partition.values())
nx.draw_networkx_edges(call_graph, pos=pos, alpha=0.5)
plt.show()

# %% [markdown]
# Two remarks are in order with regard to the clustering result obtained.
#
# The first is that cluster assignment is determined inside our **create_hc** function, specifically the call
#
# `hierarchy.fcluster(Z,t=t, criterion='inconsistent')`
#
# where t is a threshold (scalar value, t=1.15 in our case) and criterion is the criterion used in forming flat clusters (of which there are five options, with *inconsistent* the default). We have specified reasonable values for these estimates but typically the user needs to optimize these base on a good understanding of the problem domain and the clustering technique.
#
# Secondly, the visualization of our clusters is not perfect because of the constraints imposed by the node positioning layout algorithm. Unfortunately, NetworkX does not  provide ideal visualization tools to improve the graph display. However, the correct interpretation is that nodes with close or similar color belong to the same cluster (despite the poor reflection of this in the visualization).

# %% [markdown]
# The dendrogram corresponding to the above illustrated partitioned graph is obtained as follows:

# %%
hierarchy.dendrogram(Z)
plt.show()

# %% [markdown]
# This dendrogram can help explain what happens as a result of the agglomerative method of hierarchical clustering. Starting at the bottom-most level, each node is assigned its own cluster. The closest pair of nodes (according to a distance function) are then merged into a new cluster. The distance matrix is recomputed, treating the merged cluster as an individual node. This process is repeated until the entire network has been merged into a single large cluster, which the top level in the dendrogram above represents. You can now understand why this method is agglomerative.
#
# The linkage function is used to determine the distance between a cluster and a node, or between two clusters, using the following possibilities:
#
# 1. Single: merge two clusters with the smallest minimum pairwise distance.
# 2. Average: merge two clusters with the smallest average pairwise distance.
# 3. Maximum or complete: merge the two clusters with the smallest maximum pairwise distance.

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Exercise 1 Start.</b>
# </div>
#
# ### Instructions
#
# > 1. How many clusters are obtained after the final step of agglomerative clustering before post-processing?
# > 2. Based on your answer above, would you consider agglomerative clustering a 'top down' approach or a 'bottom up' approach?.
# > 3. Which of the three linkage functions listed above (i.e. single, average, maximum/complete) above do you think is likely to be most sensitive to outliers? **Hint**: See this [link](http://nlp.stanford.edu/IR-book/html/htmledition/single-link-and-complete-link-clustering-1.html)

# %% [markdown]
# Your markdown answer here.
#
# 1. If I understood weel the question, 6 including the blue singleton, before the colored clusters are combined together in higher blue hierarchy at about the y=2.75 distance level.
# 2. As explained above, the agglomerative method of hierarchical clustering is a bottom-up approach starting to agglomerate from the bottom up the nodes into clusters and the different levels of clusters together up to one cluster or group a the top left of the dendrogram.
# 3. The single link linkage consider that the similarity of two clusters is the similarity of their most SIMILAR MEMBERS where the clusters are the closest to each other remaining local in nature. As said in the stanford link (http://nlp.stanford.edu/IR-book/html/htmledition/single-link-and-complete-link-clustering-1.html) more distant parts of the cluster and the clusters' overall structure are not taken into account. On the contrary, the maximum or complete linkage clustering takes the opposite approach considering that the similarity of two clusters is the similarity of their most DISSIMILAR MEMBERS which boils down to selecting the most compact cluster pairs whose merge have the smallest diameters. This link merge criterion is by nature non local and considers that the entire structure of the clustering can influence merge decisions. This way, it gives outliers a big influence on the final clustering. The downside of the single linkage is the "chaining effect" producing straggling clusters by extending chains of points over long distances without regard to the overall shape of the emerging cluster. The complete linkage avoids this but its downside is to pay too much attention to outliers. As shown in http://nlp.stanford.edu/IR-book/completelink.html, average linkage clustering is a compromise between the two methods mitigating the downsides of both previous methods: reducing sensitivity of complete-link clustering to outliers and the chaining tendency of single-link clustering. Other methods are the centroid and Ward linkage to set the measure of cluster distance.

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Exercise 1 End.</b>
# </div>
# > **Exercise complete**:

# %% [markdown]
# ### 2.1 Block models

# %% [markdown]
# A graph network can be simplified using block models, in which all nodes in a cluster are merged into a single node. Relationships between original nodes become aggregated into relationships between blocks or communities.
#
# You can use results from your hierarchical clustering to create the block model. NetworkX has a function to build a block model which accepts the graph model and cluster information from the hierarchical clustering, as illustrated below.

# %%
M=nx.blockmodel(call_graph,blk_clusters.values())

# %%
plt.figure(figsize=(10,10))
plt.axis('off')

pos = nx.spring_layout(M)

nx.draw_networkx_nodes(M, pos=pos, node_color='#11DD11')
nx.draw_networkx_edges(M, pos=pos, alpha=0.5)
plt.show()

# %% [markdown]
# ## 3. Community detection

# %% [markdown]
# ***The Louvain Modularity Maximization Approach.***

# %% [markdown]
# The Louvain method is one of the most widely-used methods for detecting communities in large networks. It was developed by a team of researchers at the the Université catholique de Louvain. It can unveil hierarchies of communities, and allows you to zoom within communities to discover sub-communities, sub-sub-communities, and so forth. The modularity QQ quantifies how good a "community" or partition is, and is defined as:
#
# $$Q_c =\frac{1}{2m}\sum _{(ij)} \left [ A_{ij}-\frac{k_ik_j}{2m} \right] \delta(c_i, c_j)$$
#
# The higher the $Q_c$ of a community is, the better the partition is.
#
# The Louvain method is a greedy optimization method that attempts to optimize the "modularity" of a partition of the network via two steps:
#
# 1. Locally optimize the modularity to identify "small" communities.
# 2. Aggregate nodes belonging to the same community, and create a new network with aggregated nodes as individual nodes.
#
# Steps 1 and 2 are then repeated until a maximum of modularity results in a hierarchy of communities being produced.
#
# Now you have the opportunity to identify communities in the “Family & Friends” call data set. First, compute the best partition.

# %%
louvain_partition = community.best_partition(call_graph)

# %% [markdown]
# Then you can identify and label the communities similarly to what you did when using agglomerative hierarchical clustering.

# %%
pos = nx.spring_layout(call_graph)
nx.draw_networkx_nodes(call_graph, pos, cmap=plt.cm.RdYlBu, node_color=louvain_partition.values())
nx.draw_networkx_edges(call_graph, pos, alpha=0.5)
plt.axis('off')
plt.show()

# %% [markdown]
# As remarked above, the visualization of our clusters is not perfect because of the constraints imposed by the node positioning layout algorithm. The correct interpretation is that nodes with close or similar color belong to the same cluster (despite the poor reflection of this in the visualization).

# %% [markdown]
# ## 4. Spectral graph partitioning

# %% [markdown]
# Spectral graph partitioning and clustering is based on the spectrum — the eigenvalues and associated eigenvectors — of the Laplacian matrix corresponding to a given graph. The approach is mathematically complex but involves performing a $k$-means clustering on a spectral projection of the graph with $k$=2, using an adjacency matrix as the affinity. A schematic illustration of the process is depicted in the figure below.
#
# **Optional**: You can read more about spectral graph processing [here](https://devblogs.nvidia.com/parallelforall/fast-spectral-graph-partitioning-gpus/).

# %% [markdown]
# <img src="img/spectral_graph_part.png", width=750, height=550>

# %% [markdown]
# Now apply spectral graph partitioning to your call graph and visualize the resulting community structure. You can read more about [Scikit-Learn](http://scikit-learn.org/stable/index.html) and the [Spectral Clustering](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.SpectralClustering.html) function utilized in this section. Spectral graph partitioning needs input of the number of clusters sought (default setting is 8), and there are various approaches one can take to optimize the final number of clusters depending on problem domain knowledge. Below we use $k=5$

# %%
# Create the spectral partition using the spectral clustering function from Scikit-Learn.
spectral_partition = spc(call_adjmatrix.as_matrix(), 5, assign_labels='discretize')

# %%
pos = nx.spring_layout(call_graph)
nx.draw_networkx_nodes(call_graph, pos, cmap=plt.cm.RdYlBu, node_color=spectral_partition)
nx.draw_networkx_edges(call_graph, pos, alpha=0.5)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 5. Submit your notebook
#
# Please make sure that you:
# - Perform a final "Save and Checkpoint";
# - Download a copy of the notebook in ".ipynb" format to your local machine using "File", "Download as", and "IPython Notebook (.ipynb)"; and
# - Submit a copy of this file to the online campus.
